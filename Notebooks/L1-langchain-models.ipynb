# %%
from graphviz import Digraph

dot = Digraph()
dot.attr('node', shape='box', style='filled', color='lightgrey')

# Add nodes with custom colors
dot.node('A', 'Models', fillcolor='#87CEFA')  
dot.node('B', 'Language Models', fillcolor='#87CEFA')  
dot.node('C', 'Embedding Models', fillcolor='#FFA07A') 
dot.node('D', 'closed-source', fillcolor="#77A076")  
dot.node('E', 'open-source', fillcolor="#77A076")  
dot.node('F', 'OPENAI', fillcolor="#77A076")  
dot.node('G', 'GEMINI', fillcolor="#77A076")
dot.node('H', 'HuggingFace (API)', fillcolor="#77A076")
dot.node('I', 'HuggingFace (Locally)', fillcolor="#77A076")

# Add edges
dot.edges(['AB', 'AC', 'BD', 'BE', 'DF', 'DG', 'EH', 'EI'])

# Graph style settings
dot.attr(rankdir='TB')  # Top-to-bottom layout
dot.attr('edge', arrowhead='vee')  # Arrow style

# Display
dot

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ### **OpenAI - GPT**

# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(
    model="gpt-4",
)

response = model.invoke("What is the capital of Turkey?")
response.content
# Out:
# 'Ankara is the capital of Turkey.'

# %% [markdown]
# ### **Google - GEMINI**

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",
)

response = model.invoke("What is the capital of France?")
response.content
# Out:
# 'Paris'

# %% [markdown]
# ### **HuggingFace - Inference API Key**

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint

llm = HuggingFaceEndpoint(
        repo_id="meta-llama/Llama-3.1-8B-Instruct",
        task="text-generation",
        provider="hf-inference",
    )

model = ChatHuggingFace(llm=llm)

response = model.invoke("what is the capital of Italy?")
print(response.content)
# Out:
# The capital of Italy is Rome (Italian: Roma).

# %% [markdown]
# ### **HuggingFace - Download and Run Locally**

# %% [markdown]
# - NOTE: Do not run this cell with GPU enable

# %%
from langchain_huggingface import  ChatHuggingFace, HuggingFacePipeline

llm = HuggingFacePipeline.from_model_id(
        model_id="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
        task="text-generation",
)
model = ChatHuggingFace(llm=llm)

result = model.invoke("What is the capital of Spain?")
print(result.content)

# %% [markdown]
# ### Huggingface model available using Inference API
#
# - deepseek-ai/DeepSeek-R1-0528
# - Qwen/Qwen3-32B
# - meta-llama/Llama-3.1-8B-Instruct
# - microsoft/Phi-3.5-mini-instruct
# - mistralai/Mistral-7B-Instruct-v0.3
# - HuggingFaceH4/zephyr-7b-beta
